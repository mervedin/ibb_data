# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("dam_istanbul_weather.csv")

# %%
plt.figure(figsize=(10, 5))
sns.heatmap(df.corr(), annot=True);

# %%
sns.scatterplot(data=df, x="Rain", y="GENERAL_DAM_OCCUPANCY_RATE");
