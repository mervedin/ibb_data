# %%
1import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("dam_occupancy.csv")

# %%
df.head()
# Out:
#          DATE  GENERAL_DAM_OCCUPANCY_RATE  GENERAL_DAM_RESERVED_WATER
# 0  2005-01-01                       44.62                         388
# 1  2005-01-02                       44.62                         388
# 2  2005-01-03                       44.47                         386
# 3  2005-01-04                       44.42                         386
# 4  2005-01-05                       44.35                         385

# %%
df.isna().sum()
# Out:
# DATE                          0
# GENERAL_DAM_OCCUPANCY_RATE    0
# GENERAL_DAM_RESERVED_WATER    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5818 entries, 0 to 5817
# Data columns (total 3 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   DATE                        5818 non-null   object
#  1   GENERAL_DAM_OCCUPANCY_RATE  5818 non-null   float64
#  2   GENERAL_DAM_RESERVED_WATER  5818 non-null   int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 136.5+ KB

# %%
df["DATE"] = pd.to_datetime(df["DATE"])

# %%
plt.plot(df.DATE, df.GENERAL_DAM_OCCUPANCY_RATE)

# %%
sns.scatterplot(data=df, x="GENERAL_DAM_OCCUPANCY_RATE", y="GENERAL_DAM_RESERVED_WATER");

# %%
df.shape
# Out:
# (5818, 3)

# %%
df.sort_values("DATE", inplace=True)

# %% [markdown]
# ## Model

# %%
def create_dataset(dataset, window_size=30):
    data_x, data_y = [], []
    for i in range(0,dataset.shape[0]-window_size-1, 1):
        data_x.append([data for data in dataset[i:i+window_size]])
        data_y.append(dataset[i+window_size])
        
    return np.array(data_x), np.array(data_y)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
data = df["GENERAL_DAM_OCCUPANCY_RATE"].values
data = scaler.fit_transform(data.reshape(-1, 1))

# %%
train = data[:4017]
test = data[4017:]

# %%
X_train , y_train = create_dataset(train)
X_test , y_test = create_dataset(test)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM

# %%
model = Sequential()
model.add(LSTM(15, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(LSTM(15, return_sequences=True))
model.add(LSTM(15))
model.add(Dense(1))
model.compile(loss="mean_squared_error", optimizer="adam")

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_9 (LSTM)                (None, 30, 15)            1020
# _________________________________________________________________
# lstm_10 (LSTM)               (None, 30, 15)            1860
# _________________________________________________________________
# lstm_11 (LSTM)               (None, 15)                1860
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 16
# =================================================================
# Total params: 4,756
# Trainable params: 4,756
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=16, verbose=1)
# Out:
# Train on 3986 samples, validate on 1770 samples
# Epoch 1/50
# 3986/3986 [==============================] - 18s 5ms/sample - loss: 0.0137 - val_loss: 0.0019
# Epoch 2/50
# 3986/3986 [==============================] - 15s 4ms/sample - loss: 0.0014 - val_loss: 0.0012
# Epoch 3/50
# 3986/3986 [==============================] - 16s 4ms/sample - loss: 7.0221e-04 - val_loss: 5.8006e-04
# Epoch 4/50
# 3986/3986 [==============================] - 17s 4ms/sample - loss: 5.2418e-04 - val_loss: 4.0295e-04
# Epoch 5/50
# 3986/3986 [==============================] - 17s 4ms/sample - loss: 4.6227e-04 - val_loss: 7.6747e-04
# Epoch 6/50
# 3986/3986 [==============================] - 18s 5ms/sample - loss: 4.4762e-04 - val_loss: 5.4718e-04
# Epoch 7/50
# 3986/3986 [==============================] - 17s 4ms/sample - loss: 3.9837e-04 - val_loss: 6.8499e-04
# Epoch 8/50
# 3986/3986 [==============================] - 17s 4ms/sample - loss: 3.7580e-04 - val_loss: 5.0614e-04
# Epoch 9/50
# 3986/3986 [==============================] - 17s 4ms/sample - loss: 3.4932e-04 - val_loss: 6.3887e-04
# Epoch 10/50
# 3986/3986 [==============================] - 18s 4ms/sample - loss: 3.3114e-04 - val_loss: 2.3226e-04
# Epoch 11/50
# 3986/3986 [==============================] - 18s 4ms/sample - loss: 3.3111e-04 - val_loss: 8.2273e-04
# Epoch 12/50
# 3986/3986 [==============================] - 17s 4ms/sample - loss: 2.9090e-04 - val_loss: 1.9232e-04
# Epoch 13/50
# 3986/3986 [==============================] - 18s 4ms/sample - loss: 2.5750e-04 - val_loss: 1.9040e-04
# Epoch 14/50
# 3986/3986 [==============================] - 20s 5ms/sample - loss: 2.4922e-04 - val_loss: 5.3703e-04
# Epoch 15/50
# 3986/3986 [==============================] - 23s 6ms/sample - loss: 2.3767e-04 - val_loss: 3.2447e-04
# Epoch 16/50
# 3986/3986 [==============================] - 23s 6ms/sample - loss: 2.1147e-04 - val_loss: 1.3184e-04
# Epoch 17/50
# 3986/3986 [==============================] - 20s 5ms/sample - loss: 1.8366e-04 - val_loss: 1.3734e-04
# Epoch 18/50
# 3986/3986 [==============================] - 20s 5ms/sample - loss: 1.6039e-04 - val_loss: 2.1087e-04
# Epoch 19/50
# 3986/3986 [==============================] - 21s 5ms/sample - loss: 1.3902e-04 - val_loss: 9.0272e-05
# Epoch 20/50
# 3986/3986 [==============================] - 21s 5ms/sample - loss: 1.5005e-04 - val_loss: 1.7373e-04
# Epoch 21/50
# 3986/3986 [==============================] - 20s 5ms/sample - loss: 1.4605e-04 - val_loss: 7.9407e-05
# Epoch 22/50
# 3986/3986 [==============================] - 20s 5ms/sample - loss: 1.1056e-04 - val_loss: 7.6499e-05
# Epoch 23/50
# 3986/3986 [==============================] - 21s 5ms/sample - loss: 1.0072e-04 - val_loss: 1.5077e-04
# Epoch 24/50
# 3986/3986 [==============================] - 21s 5ms/sample - loss: 1.0592e-04 - val_loss: 5.5597e-05
# Epoch 25/50
# 3986/3986 [==============================] - 21s 5ms/sample - loss: 8.8728e-05 - val_loss: 5.7506e-05
# Epoch 26/50
# 3986/3986 [==============================] - 20s 5ms/sample - loss: 8.5103e-05 - val_loss: 4.9146e-05
# Epoch 27/50
# 3986/3986 [==============================] - 20s 5ms/sample - loss: 7.1468e-05 - val_loss: 5.5969e-04
# Epoch 28/50
# 3986/3986 [==============================] - 21s 5ms/sample - loss: 9.1954e-05 - val_loss: 4.4310e-05
# Epoch 29/50
# 3986/3986 [==============================] - 19s 5ms/sample - loss: 6.8416e-05 - val_loss: 4.5342e-05
# Epoch 30/50
# 3986/3986 [==============================] - 20s 5ms/sample - loss: 7.5343e-05 - val_loss: 6.0410e-05
# Epoch 31/50
# 3986/3986 [==============================] - 20s 5ms/sample - loss: 7.2748e-05 - val_loss: 7.4940e-05
# Epoch 32/50
# 3986/3986 [==============================] - 20s 5ms/sample - loss: 6.3230e-05 - val_loss: 3.7844e-05
# Epoch 33/50
# 3986/3986 [==============================] - 20s 5ms/sample - loss: 6.9970e-05 - val_loss: 1.4201e-04
# Epoch 34/50
# 3986/3986 [==============================] - 20s 5ms/sample - loss: 5.8572e-05 - val_loss: 7.9491e-05
# Epoch 35/50
# 3986/3986 [==============================] - 20s 5ms/sample - loss: 5.5122e-05 - val_loss: 3.3535e-05
# Epoch 36/50
# 3986/3986 [==============================] - 20s 5ms/sample - loss: 4.8395e-05 - val_loss: 3.4086e-05
# Epoch 37/50
# 3986/3986 [==============================] - 20s 5ms/sample - loss: 5.9645e-05 - val_loss: 4.4490e-05
# Epoch 38/50
# 3986/3986 [==============================] - 20s 5ms/sample - loss: 4.7869e-05 - val_loss: 3.2248e-05
# Epoch 39/50
# 3986/3986 [==============================] - 20s 5ms/sample - loss: 5.4399e-05 - val_loss: 4.4856e-05
# Epoch 40/50
# 3986/3986 [==============================] - 19s 5ms/sample - loss: 4.6723e-05 - val_loss: 4.3197e-05
# Epoch 41/50
# 3986/3986 [==============================] - 20s 5ms/sample - loss: 4.8360e-05 - val_loss: 5.1685e-05
# Epoch 42/50
# 3986/3986 [==============================] - 20s 5ms/sample - loss: 5.4530e-05 - val_loss: 2.4007e-05
# Epoch 43/50
# 3986/3986 [==============================] - 20s 5ms/sample - loss: 5.1372e-05 - val_loss: 2.4511e-05
# Epoch 44/50
# 3986/3986 [==============================] - 20s 5ms/sample - loss: 4.0777e-05 - val_loss: 6.3885e-05
# Epoch 45/50
# 3986/3986 [==============================] - 20s 5ms/sample - loss: 4.3779e-05 - val_loss: 2.3765e-05
# Epoch 46/50
# 3986/3986 [==============================] - 20s 5ms/sample - loss: 4.2915e-05 - val_loss: 2.6078e-05
# Epoch 47/50
# 3986/3986 [==============================] - 20s 5ms/sample - loss: 4.0020e-05 - val_loss: 3.7367e-05
# Epoch 48/50
# 3986/3986 [==============================] - 20s 5ms/sample - loss: 3.8841e-05 - val_loss: 5.9890e-05
# Epoch 49/50
# 3986/3986 [==============================] - 20s 5ms/sample - loss: 3.6633e-05 - val_loss: 2.7013e-05
# Epoch 50/50
# 3986/3986 [==============================] - 21s 5ms/sample - loss: 4.4588e-05 - val_loss: 2.1067e-05

# %%
train_preds = model.predict(X_train)
test_preds = model.predict(X_test)

# %%
plt.figure(figsize=(15, 10))
plt.plot(train)
plt.plot(train_preds)
plt.legend(["Train", "Predicted Train"])

# %%
plt.figure(figsize=(15, 10))
plt.plot(test)
plt.plot(test_preds)
plt.legend(["Test", "Predicted Test"])
