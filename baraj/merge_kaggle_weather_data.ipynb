# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

# %%
df = pd.read_csv("Istanbul Weather Data.csv", )

# %%
df.head()
# Out:
#      DateTime             Condition  Rain  MaxTemp  MinTemp   SunRise  \
# 0  02.09.2019         Partly cloudy   0.0       27       22  06:32:00
# 1  01.09.2019         Partly cloudy   0.0       27       22  06:31:00
# 2  31.08.2019  Patchy rain possible   0.5       26       22  06:30:00
# 3  30.08.2019         Partly cloudy   0.0       27       22  06:29:00
# 4  29.08.2019         Partly cloudy   0.0       27       23  06:27:00
#
#      SunSet MoonRise   MoonSet  AvgWind  AvgHumidity  AvgPressure
# 0  19:37:00  9:52:00  21:45:00       23           66         1012
# 1  19:38:00  8:37:00  21:13:00       21           66         1011
# 2  19:40:00  7:21:00  20:40:00       22           63         1015
# 3  19:42:00   6:4:00   20:5:00       20           64         1016
# 4  19:43:00  4:47:00  19:26:00       24           61         1015

# %%
df["DATE"] = pd.to_datetime(df["DateTime"])
df.drop("DateTime", axis=1)
# Out:
#                  Condition  Rain  MaxTemp  MinTemp   SunRise    SunSet  \
# 0            Partly cloudy  0.00       27       22  06:32:00  19:37:00
# 1            Partly cloudy  0.00       27       22  06:31:00  19:38:00
# 2     Patchy rain possible  0.50       26       22  06:30:00  19:40:00
# 3            Partly cloudy  0.00       27       22  06:29:00  19:42:00
# 4            Partly cloudy  0.00       27       23  06:27:00  19:43:00
# ...                    ...   ...      ...      ...       ...       ...
# 3891              Overcast  4.32        5        3  08:29:00  17:50:00
# 3892                  Mist  2.91        5        3  08:29:00  17:49:00
# 3893              Overcast  0.08        5        3  08:29:00  17:48:00
# 3894              Overcast  4.48        4        1  08:29:00  17:48:00
# 3895         Partly cloudy  0.23        5        2  08:29:00  17:47:00
#
#       MoonRise   MoonSet  AvgWind  AvgHumidity  AvgPressure       DATE
# ...

# %%
df.isna().sum()
# Out:
# DateTime         0
# Condition        0
# Rain             0
# MaxTemp          0
# MinTemp          0
# SunRise          0
# SunSet           0
# MoonRise       132
# MoonSet        131
# AvgWind          0
# AvgHumidity      0
# AvgPressure      0
# DATE             0
# dtype: int64

# %%
df.drop(["MoonRise", "MoonSet"], axis=1)
# Out:
#         DateTime             Condition  Rain  MaxTemp  MinTemp   SunRise  \
# 0     02.09.2019         Partly cloudy  0.00       27       22  06:32:00
# 1     01.09.2019         Partly cloudy  0.00       27       22  06:31:00
# 2     31.08.2019  Patchy rain possible  0.50       26       22  06:30:00
# 3     30.08.2019         Partly cloudy  0.00       27       22  06:29:00
# 4     29.08.2019         Partly cloudy  0.00       27       23  06:27:00
# ...          ...                   ...   ...      ...      ...       ...
# 3891  05.01.2009              Overcast  4.32        5        3  08:29:00
# 3892  04.01.2009                  Mist  2.91        5        3  08:29:00
# 3893  03.01.2009              Overcast  0.08        5        3  08:29:00
# 3894  02.01.2009              Overcast  4.48        4        1  08:29:00
# 3895  01.01.2009         Partly cloudy  0.23        5        2  08:29:00
#
#         SunSet  AvgWind  AvgHumidity  AvgPressure       DATE
# ...

# %%
df.shape
# Out:
# (3896, 13)

# %%
Counter(df.DATE.dt.year)
# Out:
# Counter({2019: 245,
#          2018: 365,
#          2017: 365,
#          2016: 366,
#          2015: 365,
#          2014: 365,
#          2013: 365,
#          2012: 365,
#          2011: 365,
#          2010: 365,
#          2009: 365})

# %%
dam_df = pd.read_csv("dam_occupancy.csv")

# %%
dam_df["DATE"] = pd.to_datetime(dam_df["DATE"])

# %%
df_merged = pd.merge(dam_df, df, how="inner", on="DATE")

# %%
df_merged.shape
# Out:
# (3896, 15)

# %%
df_merged.head()
# Out:
#         DATE  GENERAL_DAM_OCCUPANCY_RATE  GENERAL_DAM_RESERVED_WATER  \
# 0 2009-01-01                       34.51                         300
# 1 2009-01-02                       34.87                         303
# 2 2009-01-03                       35.28                         306
# 3 2009-01-04                       35.88                         312
# 4 2009-01-05                       37.32                         324
#
#      DateTime      Condition  Rain  MaxTemp  MinTemp   SunRise    SunSet  \
# 0  01.01.2009  Partly cloudy  0.23        5        2  08:29:00  17:47:00
# 1  01.02.2009         Cloudy  0.02        7        3  08:15:00  18:21:00
# 2  01.03.2009  Partly cloudy  0.26        8        1  07:39:00  18:55:00
# 3  01.04.2009          Sunny  0.00       17        9  06:48:00  19:29:00
# 4  01.05.2009  Partly cloudy  2.23       20       10  06:02:00   20:1:00
#
#    MoonRise   MoonSet  AvgWind  AvgHumidity  AvgPressure
# ...

# %%
df_merged.to_csv("dam_istanbul_weather.csv", index=False)
